# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import requests
import os
import pandas as pd
from selenium import webdriver

# %%
column_names = ['date','away_team','away_1st_inn','home_team','home_1st_inn']

total_df = pd.DataFrame(columns = column_names)
total_df
# Out:
# Empty DataFrame
# Columns: [date, away_team, away_1st_inn, home_team, home_1st_inn]
# Index: []

# %%
url = 'https://www.baseball-reference.com/boxes/?year=2021&month=5&day=12'

response = requests.get(url)

soup = bs(response.text, 'html.parser')

# %%
results = soup.find_all('td', class_='right gamelink')
string_results = str(results)
soup = bs(string_results)
# print(results)
# FOR LOOP TO CREATE EACH SPECIFIC LINK TO EACH GAME'S SCORES
url_list = []
for a in soup.find_all('a', href=True):
    link = 'https://www.baseball-reference.com' + a['href']
    url_list.append(link)
    print(link)
# Out:
# https://www.baseball-reference.com/boxes/COL/COL202105122.shtml
# https://www.baseball-reference.com/boxes/CLE/CLE202105120.shtml
# https://www.baseball-reference.com/boxes/COL/COL202105121.shtml
# https://www.baseball-reference.com/boxes/WAS/WAS202105120.shtml
# https://www.baseball-reference.com/boxes/BOS/BOS202105120.shtml
# https://www.baseball-reference.com/boxes/DET/DET202105120.shtml
# https://www.baseball-reference.com/boxes/TBA/TBA202105120.shtml
# https://www.baseball-reference.com/boxes/ATL/ATL202105120.shtml
# https://www.baseball-reference.com/boxes/MIL/MIL202105120.shtml
# https://www.baseball-reference.com/boxes/CHA/CHA202105120.shtml
# https://www.baseball-reference.com/boxes/HOU/HOU202105120.shtml
# https://www.baseball-reference.com/boxes/ARI/ARI202105120.shtml
# https://www.baseball-reference.com/boxes/LAN/LAN202105120.shtml
# https://www.baseball-reference.com/boxes/NYN/NYN202105120.shtml
# https://www.baseball-reference.com/boxes/PIT/PIT202105120.shtml

# %%
# LOOPING THROUGH EACH GAME URL TO PULL BOX INFO
# date = soup.find_all('div', class_="scorebox_meta")[0]
# dt = 1
# for d in date:
#     if dt == 2:
# #     if dt == 2 or dt == 3:
#         print(d.text)
#     dt+=1
game_date_list = []
away_team_list = []
away_score_list = []
home_team_list = []
home_score_list = []
for url in url_list:
    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    
    date = soup.find_all('div', class_="scorebox_meta")[0]
    dt = 1
    for d in date:
        if dt == 2:
            final_date = d.text
            print(final_date)
            game_date_list.append(final_date)
#             print(d.text)

        dt+=1
    #LOCATES A SPECIFC 'TR'. SET INDEXES TO ONLY PULL TEAM ROWS    
    final_tr1 = soup.find_all('tr')[1]
    final_tr2 = soup.find_all('tr')[2]
    y = 1
    for r in final_tr1:
        if y == 4:
            away_team = r.text
            print(away_team)
            away_team_list.append(away_team)
        elif y == 6:
            away_tr = r.text
            print(away_tr)
            away_score_list.append(away_tr)
            
        y+=1
    y = 1    
    for r in final_tr2:
        if y == 4:
            home_team = r.text
            print(home_team)
            home_team_list.append(home_team)
        if y == 6:
            home_tr = r.text
            print(home_tr)
            home_score_list.append(home_tr)
        y+=1
# Out:
# Wednesday, May 12, 2021
# San Diego Padres
# 0
# Colorado Rockies
# 0
# Wednesday, May 12, 2021
# Chicago Cubs
# 0
# Cleveland Indians
# 0
# Wednesday, May 12, 2021
# San Diego Padres
# 0
# Colorado Rockies
# 1
# Wednesday, May 12, 2021
# Philadelphia Phillies
# 0
# Washington Nationals
# 0
# Wednesday, May 12, 2021
# Oakland Athletics
# 0
# Boston Red Sox
# 1
# Wednesday, May 12, 2021
# Kansas City Royals
# 2
# Detroit Tigers
# 0
# Wednesday, May 12, 2021
# New York Yankees
# 0
# Tampa Bay Rays
# 0
# Wednesday, May 12, 2021
# Toronto Blue Jays
# 0
# Atlanta Braves
# 0
# Wednesday, May 12, 2021
# St. Louis Cardinals
# 0
# Milwaukee Brewers
# 0
# Wednesday, May 12, 2021
# Minnesota Twins
# 1
# Chicago White Sox
# 2
# Wednesday, May 12, 2021
# Los Angeles Angels
# 0
# Houston Astros
# 3
# Wednesday, May 12, 2021
# Miami Marlins
# 2
# Arizona Diamondbacks
# 1
# Wednesday, May 12, 2021
# Seattle Mariners
# 0
# Los Angeles Dodgers
# 0
# Wednesday, May 12, 2021
# Baltimore Orioles
# 0
# New York Mets
# 0
# Wednesday, May 12, 2021
# Cincinnati Reds
# 0
# Pittsburgh Pirates
# 0

# %%
dict = {'date': game_date_list,
        'away_team': away_team_list,
       'away_1st_inn': away_score_list,
       'home_team': home_team_list,
       'home_1st_inn': home_score_list}

# %%
df = pd.DataFrame(dict)
df
# Out:
#                        date              away_team away_1st_inn  \
# 0   Wednesday, May 12, 2021       San Diego Padres            0
# 1   Wednesday, May 12, 2021           Chicago Cubs            0
# 2   Wednesday, May 12, 2021       San Diego Padres            0
# 3   Wednesday, May 12, 2021  Philadelphia Phillies            0
# 4   Wednesday, May 12, 2021      Oakland Athletics            0
# 5   Wednesday, May 12, 2021     Kansas City Royals            2
# 6   Wednesday, May 12, 2021       New York Yankees            0
# 7   Wednesday, May 12, 2021      Toronto Blue Jays            0
# 8   Wednesday, May 12, 2021    St. Louis Cardinals            0
# 9   Wednesday, May 12, 2021        Minnesota Twins            1
# 10  Wednesday, May 12, 2021     Los Angeles Angels            0
# 11  Wednesday, May 12, 2021          Miami Marlins            2
# 12  Wednesday, May 12, 2021       Seattle Mariners            0
# 13  Wednesday, May 12, 2021      Baltimore Orioles            0
# 14  Wednesday, May 12, 2021        Cincinnati Reds            0
#
#                home_team home_1st_inn
# 0       Colorado Rockies            0
# 1      Cleveland Indians            0
# 2       Colorado Rockies            1
# 3   Washington Nationals            0
# 4         Boston Red Sox            1
# 5         Detroit Tigers            0
# 6         Tampa Bay Rays            0
# 7         Atlanta Braves            0
# 8      Milwaukee Brewers            0
# 9      Chicago White Sox            2
# 10        Houston Astros            3
# 11  Arizona Diamondbacks            1
# 12   Los Angeles Dodgers            0
# 13         New York Mets            0
# 14    Pittsburgh Pirates            0

# %%
total_df = total_df.append(df, ignore_index = True)
total_df.tail(25)
# Out:
#                         date              away_team away_1st_inn  \
# 515    Tuesday, May 11, 2021     Kansas City Royals            0
# 516    Tuesday, May 11, 2021      Baltimore Orioles            0
# 517    Tuesday, May 11, 2021       New York Yankees            1
# 518    Tuesday, May 11, 2021      Toronto Blue Jays            0
# 519    Tuesday, May 11, 2021    St. Louis Cardinals            0
# 520    Tuesday, May 11, 2021        Minnesota Twins            0
# 521    Tuesday, May 11, 2021     Los Angeles Angels            0
# 522    Tuesday, May 11, 2021       San Diego Padres            0
# 523    Tuesday, May 11, 2021          Miami Marlins            0
# 524    Tuesday, May 11, 2021       Seattle Mariners            1
# 525  Wednesday, May 12, 2021       San Diego Padres            0
# 526  Wednesday, May 12, 2021           Chicago Cubs            0
# 527  Wednesday, May 12, 2021       San Diego Padres            0
# 528  Wednesday, May 12, 2021  Philadelphia Phillies            0
# 529  Wednesday, May 12, 2021      Oakland Athletics            0
# 530  Wednesday, May 12, 2021     Kansas City Royals            2
# 531  Wednesday, May 12, 2021       New York Yankees            0
# 532  Wednesday, May 12, 2021      Toronto Blue Jays            0
# 533  Wednesday, May 12, 2021    St. Louis Cardinals            0
# 534  Wednesday, May 12, 2021        Minnesota Twins            1
# 535  Wednesday, May 12, 2021     Los Angeles Angels            0
# 536  Wednesday, May 12, 2021          Miami Marlins            2
# 537  Wednesday, May 12, 2021       Seattle Mariners            0
# 538  Wednesday, May 12, 2021      Baltimore Orioles            0
# 539  Wednesday, May 12, 2021        Cincinnati Reds            0
#
#                 home_team home_1st_inn
# 515        Detroit Tigers            0
# 516         New York Mets            0
# 517        Tampa Bay Rays            0
# 518        Atlanta Braves            1
# 519     Milwaukee Brewers            0
# 520     Chicago White Sox            0
# 521        Houston Astros            0
# 522      Colorado Rockies            1
# 523  Arizona Diamondbacks            0
# 524   Los Angeles Dodgers            0
# 525      Colorado Rockies            0
# 526     Cleveland Indians            0
# 527      Colorado Rockies            1
# 528  Washington Nationals            0
# 529        Boston Red Sox            1
# 530        Detroit Tigers            0
# 531        Tampa Bay Rays            0
# 532        Atlanta Braves            0
# 533     Milwaukee Brewers            0
# 534     Chicago White Sox            2
# 535        Houston Astros            3
# 536  Arizona Diamondbacks            1
# 537   Los Angeles Dodgers            0
# 538         New York Mets            0
# 539    Pittsburgh Pirates            0

# %%
total_df.to_csv('full_firstinning_data.csv', index=False)

# %%
# total_df.to_csv('april_firstinning_data.csv', index=False)

# %%
# april_df = pd.read_csv('april_firstinning_data.csv')
# april_df
# Out:
#                         date             away_team  away_1st_inn  \
# 0    Thursday, April 1, 2021     Toronto Blue Jays             0
# 1    Thursday, April 1, 2021     Cleveland Indians             0
# 2    Thursday, April 1, 2021       Minnesota Twins             0
# 3    Thursday, April 1, 2021    Pittsburgh Pirates             2
# 4    Thursday, April 1, 2021        Atlanta Braves             0
# ..                       ...                   ...           ...
# 377   Friday, April 30, 2021    Kansas City Royals             0
# 378   Friday, April 30, 2021      Colorado Rockies             1
# 379   Friday, April 30, 2021     Baltimore Orioles             0
# 380   Friday, April 30, 2021  San Francisco Giants             1
# 381   Friday, April 30, 2021    Los Angeles Angels             2
#
#                  home_team  home_1st_inn
# 0         New York Yankees             0
# 1           Detroit Tigers             2
# 2        Milwaukee Brewers             0
# 3             Chicago Cubs             1
# 4    Philadelphia Phillies             1
# ..                     ...           ...
# 377        Minnesota Twins             0
# 378   Arizona Diamondbacks             0
# 379      Oakland Athletics             0
# 380       San Diego Padres             1
# 381       Seattle Mariners             1
#
# [382 rows x 5 columns]

# %%
full_df = pd.read_csv('full_firstinning_data.csv')
full_df.tail(10)
# Out:
#                         date            away_team  away_1st_inn  \
# 530  Wednesday, May 12, 2021   Kansas City Royals             2
# 531  Wednesday, May 12, 2021     New York Yankees             0
# 532  Wednesday, May 12, 2021    Toronto Blue Jays             0
# 533  Wednesday, May 12, 2021  St. Louis Cardinals             0
# 534  Wednesday, May 12, 2021      Minnesota Twins             1
# 535  Wednesday, May 12, 2021   Los Angeles Angels             0
# 536  Wednesday, May 12, 2021        Miami Marlins             2
# 537  Wednesday, May 12, 2021     Seattle Mariners             0
# 538  Wednesday, May 12, 2021    Baltimore Orioles             0
# 539  Wednesday, May 12, 2021      Cincinnati Reds             0
#
#                 home_team  home_1st_inn
# 530        Detroit Tigers             0
# 531        Tampa Bay Rays             0
# 532        Atlanta Braves             0
# 533     Milwaukee Brewers             0
# 534     Chicago White Sox             2
# 535        Houston Astros             3
# 536  Arizona Diamondbacks             1
# 537   Los Angeles Dodgers             0
# 538         New York Mets             0
# 539    Pittsburgh Pirates             0

# %%
total_df.loc[(total_df['away_team'] == 'Cleveland Indians') |
             (total_df['away_team'] == 'Seattle Mariners') | 
             (total_df['home_team'] == 'Cleveland Indians') | 
             (total_df['home_team'] == 'Seattle Mariners')]
# Out:
#                         date             away_team away_1st_inn  \
# 1    Thursday, April 1, 2021     Cleveland Indians            0
# 12   Thursday, April 1, 2021  San Francisco Giants            0
# 19     Friday, April 2, 2021  San Francisco Giants            0
# 22   Saturday, April 3, 2021     Cleveland Indians            0
# 33   Saturday, April 3, 2021  San Francisco Giants            0
# ..                       ...                   ...          ...
# 500      Sunday, May 9, 2021      Seattle Mariners            0
# 511    Tuesday, May 11, 2021          Chicago Cubs            0
# 524    Tuesday, May 11, 2021      Seattle Mariners            1
# 526  Wednesday, May 12, 2021          Chicago Cubs            0
# 537  Wednesday, May 12, 2021      Seattle Mariners            0
#
#                home_team home_1st_inn
# 1         Detroit Tigers            2
# 12      Seattle Mariners            0
# 19      Seattle Mariners            0
# 22        Detroit Tigers            2
# 33      Seattle Mariners            0
# ..                   ...          ...
# 500        Texas Rangers            0
# 511    Cleveland Indians            0
# 524  Los Angeles Dodgers            0
# 526    Cleveland Indians            0
# 537  Los Angeles Dodgers            0
#
# [71 rows x 5 columns]
