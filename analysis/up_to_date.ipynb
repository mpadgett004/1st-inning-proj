# %%
# pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 4.6 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
from splinter import Browser
from bs4 import BeautifulSoup as bs
import requests
import os
import pandas as pd

# %%
full_df = pd.read_csv('full_firstinning_data.csv')
full_df
# Out:
#                         date             away_team  away_1st_inn  \
# 0    Thursday, April 1, 2021     Toronto Blue Jays             0
# 1    Thursday, April 1, 2021     Cleveland Indians             0
# 2    Thursday, April 1, 2021       Minnesota Twins             0
# 3    Thursday, April 1, 2021    Pittsburgh Pirates             2
# 4    Thursday, April 1, 2021        Atlanta Braves             0
# ..                       ...                   ...           ...
# 602     Monday, May 17, 2021      New York Yankees             1
# 603     Monday, May 17, 2021     Cleveland Indians             1
# 604     Monday, May 17, 2021  Arizona Diamondbacks             0
# 605     Monday, May 17, 2021      Colorado Rockies             0
# 606     Monday, May 17, 2021        Detroit Tigers             0
#
#                  home_team  home_1st_inn
# 0         New York Yankees             0
# 1           Detroit Tigers             2
# 2        Milwaukee Brewers             0
# 3             Chicago Cubs             1
# 4    Philadelphia Phillies             1
# ..                     ...           ...
# 602          Texas Rangers             0
# 603     Los Angeles Angels             1
# 604    Los Angeles Dodgers             0
# 605       San Diego Padres             3
# 606       Seattle Mariners             0
#
# [607 rows x 5 columns]

# %%
url = 'https://www.baseball-reference.com/boxes/?year=2021&month=5&day=18'

response = requests.get(url)

soup = bs(response.text, 'html.parser')

# %%
results = soup.find_all('td', class_='right gamelink')
string_results = str(results)
soup = bs(string_results)
# print(results)
# FOR LOOP TO CREATE EACH SPECIFIC LINK TO EACH GAME'S SCORES
url_list = []
for a in soup.find_all('a', href=True):
    link = 'https://www.baseball-reference.com' + a['href']
    url_list.append(link)
    print(link)
# Out:
# https://www.baseball-reference.com/boxes/CIN/CIN202105180.shtml
# https://www.baseball-reference.com/boxes/BAL/BAL202105180.shtml
# https://www.baseball-reference.com/boxes/PHI/PHI202105180.shtml
# https://www.baseball-reference.com/boxes/ATL/ATL202105180.shtml
# https://www.baseball-reference.com/boxes/TOR/TOR202105180.shtml
# https://www.baseball-reference.com/boxes/CHN/CHN202105180.shtml
# https://www.baseball-reference.com/boxes/MIN/MIN202105180.shtml
# https://www.baseball-reference.com/boxes/SLN/SLN202105180.shtml
# https://www.baseball-reference.com/boxes/TEX/TEX202105180.shtml
# https://www.baseball-reference.com/boxes/KCA/KCA202105180.shtml
# https://www.baseball-reference.com/boxes/ANA/ANA202105180.shtml
# https://www.baseball-reference.com/boxes/OAK/OAK202105180.shtml
# https://www.baseball-reference.com/boxes/LAN/LAN202105180.shtml
# https://www.baseball-reference.com/boxes/SDN/SDN202105180.shtml
# https://www.baseball-reference.com/boxes/SEA/SEA202105180.shtml

# %%
game_date_list = []
away_team_list = []
away_score_list = []
home_team_list = []
home_score_list = []
for url in url_list:
    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    
    date = soup.find_all('div', class_="scorebox_meta")[0]
    dt = 1
    for d in date:
        if dt == 2:
            final_date = d.text
            print(final_date)
            game_date_list.append(final_date)
#             print(d.text)

        dt+=1
    #LOCATES A SPECIFC 'TR'. SET INDEXES TO ONLY PULL TEAM ROWS    
    final_tr1 = soup.find_all('tr')[1]
    final_tr2 = soup.find_all('tr')[2]
    y = 1
    for r in final_tr1:
        if y == 4:
            away_team = r.text
            print(away_team)
            away_team_list.append(away_team)
        elif y == 6:
            away_tr = r.text
            print(away_tr)
            away_score_list.append(away_tr)
            
        y+=1
    y = 1    
    for r in final_tr2:
        if y == 4:
            home_team = r.text
            print(home_team)
            home_team_list.append(home_team)
        if y == 6:
            home_tr = r.text
            print(home_tr)
            home_score_list.append(home_tr)
        y+=1
# Out:
# Tuesday, May 18, 2021
# San Francisco Giants
# 0
# Cincinnati Reds
# 1
# Tuesday, May 18, 2021
# Tampa Bay Rays
# 0
# Baltimore Orioles
# 0
# Tuesday, May 18, 2021
# Miami Marlins
# 0
# Philadelphia Phillies
# 0
# Tuesday, May 18, 2021
# New York Mets
# 0
# Atlanta Braves
# 0
# Tuesday, May 18, 2021
# Boston Red Sox
# 0
# Toronto Blue Jays
# 0
# Tuesday, May 18, 2021
# Washington Nationals
# 0
# Chicago Cubs
# 0
# Tuesday, May 18, 2021
# Chicago White Sox
# 1
# Minnesota Twins
# 0
# Tuesday, May 18, 2021
# Pittsburgh Pirates
# 0
# St. Louis Cardinals
# 2
# Tuesday, May 18, 2021
# New York Yankees
# 0
# Texas Rangers
# 0
# Tuesday, May 18, 2021
# Milwaukee Brewers
# 0
# Kansas City Royals
# 0
# Tuesday, May 18, 2021
# Cleveland Indians
# 5
# Los Angeles Angels
# 1
# Tuesday, May 18, 2021
# Houston Astros
# 2
# Oakland Athletics
# 1
# Tuesday, May 18, 2021
# Arizona Diamondbacks
# 0
# Los Angeles Dodgers
# 1
# Tuesday, May 18, 2021
# Colorado Rockies
# 0
# San Diego Padres
# 0
# Tuesday, May 18, 2021
# Detroit Tigers
# 1
# Seattle Mariners
# 0

# %%
dict = {'date': game_date_list,
        'away_team': away_team_list,
       'away_1st_inn': away_score_list,
       'home_team': home_team_list,
       'home_1st_inn': home_score_list}

# %%
df = pd.DataFrame(dict)
df
# Out:
#                      date             away_team away_1st_inn  \
# 0   Tuesday, May 18, 2021  San Francisco Giants            0
# 1   Tuesday, May 18, 2021        Tampa Bay Rays            0
# 2   Tuesday, May 18, 2021         Miami Marlins            0
# 3   Tuesday, May 18, 2021         New York Mets            0
# 4   Tuesday, May 18, 2021        Boston Red Sox            0
# 5   Tuesday, May 18, 2021  Washington Nationals            0
# 6   Tuesday, May 18, 2021     Chicago White Sox            1
# 7   Tuesday, May 18, 2021    Pittsburgh Pirates            0
# 8   Tuesday, May 18, 2021      New York Yankees            0
# 9   Tuesday, May 18, 2021     Milwaukee Brewers            0
# 10  Tuesday, May 18, 2021     Cleveland Indians            5
# 11  Tuesday, May 18, 2021        Houston Astros            2
# 12  Tuesday, May 18, 2021  Arizona Diamondbacks            0
# 13  Tuesday, May 18, 2021      Colorado Rockies            0
# 14  Tuesday, May 18, 2021        Detroit Tigers            1
#
#                 home_team home_1st_inn
# 0         Cincinnati Reds            1
# 1       Baltimore Orioles            0
# 2   Philadelphia Phillies            0
# 3          Atlanta Braves            0
# 4       Toronto Blue Jays            0
# 5            Chicago Cubs            0
# 6         Minnesota Twins            0
# 7     St. Louis Cardinals            2
# 8           Texas Rangers            0
# 9      Kansas City Royals            0
# 10     Los Angeles Angels            1
# 11      Oakland Athletics            1
# 12    Los Angeles Dodgers            1
# 13       San Diego Padres            0
# 14       Seattle Mariners            0

# %%
updated_df = full_df.append(df, ignore_index = True)
updated_df.tail(25)
# Out:
#                       date             away_team away_1st_inn  \
# 597   Sunday, May 16, 2021   St. Louis Cardinals            2
# 598   Monday, May 17, 2021  San Francisco Giants            1
# 599   Monday, May 17, 2021         New York Mets            0
# 600   Monday, May 17, 2021  Washington Nationals            0
# 601   Monday, May 17, 2021     Chicago White Sox            3
# 602   Monday, May 17, 2021      New York Yankees            1
# 603   Monday, May 17, 2021     Cleveland Indians            1
# 604   Monday, May 17, 2021  Arizona Diamondbacks            0
# 605   Monday, May 17, 2021      Colorado Rockies            0
# 606   Monday, May 17, 2021        Detroit Tigers            0
# 607  Tuesday, May 18, 2021  San Francisco Giants            0
# 608  Tuesday, May 18, 2021        Tampa Bay Rays            0
# 609  Tuesday, May 18, 2021         Miami Marlins            0
# 610  Tuesday, May 18, 2021         New York Mets            0
# 611  Tuesday, May 18, 2021        Boston Red Sox            0
# 612  Tuesday, May 18, 2021  Washington Nationals            0
# 613  Tuesday, May 18, 2021     Chicago White Sox            1
# 614  Tuesday, May 18, 2021    Pittsburgh Pirates            0
# 615  Tuesday, May 18, 2021      New York Yankees            0
# 616  Tuesday, May 18, 2021     Milwaukee Brewers            0
# 617  Tuesday, May 18, 2021     Cleveland Indians            5
# 618  Tuesday, May 18, 2021        Houston Astros            2
# 619  Tuesday, May 18, 2021  Arizona Diamondbacks            0
# 620  Tuesday, May 18, 2021      Colorado Rockies            0
# 621  Tuesday, May 18, 2021        Detroit Tigers            1
#
#                  home_team home_1st_inn
# 597       San Diego Padres            0
# 598        Cincinnati Reds            0
# 599         Atlanta Braves            0
# 600           Chicago Cubs            1
# 601        Minnesota Twins            0
# 602          Texas Rangers            0
# 603     Los Angeles Angels            1
# 604    Los Angeles Dodgers            0
# 605       San Diego Padres            3
# 606       Seattle Mariners            0
# 607        Cincinnati Reds            1
# 608      Baltimore Orioles            0
# 609  Philadelphia Phillies            0
# 610         Atlanta Braves            0
# 611      Toronto Blue Jays            0
# 612           Chicago Cubs            0
# 613        Minnesota Twins            0
# 614    St. Louis Cardinals            2
# 615          Texas Rangers            0
# 616     Kansas City Royals            0
# 617     Los Angeles Angels            1
# 618      Oakland Athletics            1
# 619    Los Angeles Dodgers            1
# 620       San Diego Padres            0
# 621       Seattle Mariners            0

# %%
updated_df.to_csv('full_firstinning_data.csv', index=False)

# %%
updated_df.to_excel('analysis_innnings.xlsx', index=False)

# %%
# updated_df.to_excel('analysis_innnings.xlsm', index=False)
